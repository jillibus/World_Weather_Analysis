# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
# Import time module
import time
# Import the requests library
import requests

# Import the citipy module to determine city based on latitude and longitude
from citipy import citipy
# Import date-time-module from the datetime library
from datetime import datetime

# Import the API key
from config import weather_api_key
# Import the Google Maps API key
from config import g_key

# %%
## Google Maps URL
g_baseurl = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
gmaps.configure(api_key=g_key)
# Open Weather Map API URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list (otherwise it will be lost in memory)
coordinates = list(lat_lngs)

# %%
# Refactor the above code to create a list to hold the cities 
cities = []

# Identify the nearest cities for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then add it to the city list
    if city not in cities:
        cities.append(city)

# Determined how many cities are in your list
len(cities)
# Out:
# 787

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print('Beginning of Data Retrieval')
print('------------------------------------')

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning of Data Retrieval
# ------------------------------------

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + '&q=' + city.replace(" ","+")
    
    # Log the URL, record, set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
    # If an error is experienced, skip the city.
    except:
        print(city + " City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | nikolayevsk-na-amure
# Processing Record 3 of Set 1 | marzuq
# Processing Record 4 of Set 1 | viedma
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | rundu
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | rockingham
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | veshenskaya
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | zharkent
# Processing Record 17 of Set 1 | bereda
# Processing Record 18 of Set 1 | golovchino
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | bontang
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | sambava
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | hudiksvall
# Processing Record 28 of Set 1 | ritchie
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | hovd
# Processing Record 33 of Set 1 | umzimvubu
# umzimvubu City not found. Skipping...
# Processing Record 34 of Set 1 | harper
# Processing Record 35 of Set 1 | acarau
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | mongu
# Processing Record 41 of Set 1 | campo maior
# Processing Record 42 of Set 1 | pingxiang
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | rio claro
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | bumba
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | soyo
# Processing Record 1 of Set 2 | kijang
# Processing Record 2 of Set 2 | santiago
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | sioux lookout
# Processing Record 5 of Set 2 | barentsburg
# barentsburg City not found. Skipping...
# Processing Record 6 of Set 2 | ekhabi
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | kilindoni
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | vardo
# Processing Record 12 of Set 2 | siva
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | les escoumins
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | vigrestad
# Processing Record 17 of Set 2 | vaitupu
# vaitupu City not found. Skipping...
# Processing Record 18 of Set 2 | wakema
# Processing Record 19 of Set 2 | lazurne
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | el alto
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | belushya guba
# belushya guba City not found. Skipping...
# Processing Record 25 of Set 2 | inuvik
# Processing Record 26 of Set 2 | karratha
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | ganzhou
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | faya
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | te anau
# Processing Record 34 of Set 2 | mys shmidta
# mys shmidta City not found. Skipping...
# Processing Record 35 of Set 2 | samarai
# Processing Record 36 of Set 2 | tsihombe
# tsihombe City not found. Skipping...
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | azanka
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | taolanaro
# taolanaro City not found. Skipping...
# Processing Record 42 of Set 2 | hit
# Processing Record 43 of Set 2 | nanakuli
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | gull lake
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | praia
# Processing Record 49 of Set 2 | phan rang
# phan rang City not found. Skipping...
# Processing Record 50 of Set 2 | belaya gora
# Processing Record 1 of Set 3 | maraa
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | pilar
# Processing Record 7 of Set 3 | touba
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | safranbolu
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | morehead
# Processing Record 13 of Set 3 | bonanza
# Processing Record 14 of Set 3 | lexington
# Processing Record 15 of Set 3 | palaikastron
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | saint anthony
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | san jose
# Processing Record 20 of Set 3 | deolali
# Processing Record 21 of Set 3 | gravdal
# Processing Record 22 of Set 3 | krasnokamensk
# Processing Record 23 of Set 3 | port-gentil
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | ruatoria
# ruatoria City not found. Skipping...
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | alice springs
# Processing Record 30 of Set 3 | cayenne
# Processing Record 31 of Set 3 | ostrogozhsk
# Processing Record 32 of Set 3 | port macquarie
# Processing Record 33 of Set 3 | gao
# Processing Record 34 of Set 3 | port keats
# Processing Record 35 of Set 3 | hermanus
# Processing Record 36 of Set 3 | pangody
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | pochutla
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | aklavik
# Processing Record 42 of Set 3 | ikirun
# Processing Record 43 of Set 3 | torres
# Processing Record 44 of Set 3 | poya
# Processing Record 45 of Set 3 | prado
# Processing Record 46 of Set 3 | panguma
# Processing Record 47 of Set 3 | gushikawa
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | jinchengjiang
# jinchengjiang City not found. Skipping...
# Processing Record 3 of Set 4 | praia da vitoria
# Processing Record 4 of Set 4 | magistralnyy
# Processing Record 5 of Set 4 | tagusao
# Processing Record 6 of Set 4 | weihe
# Processing Record 7 of Set 4 | okhotsk
# Processing Record 8 of Set 4 | port hedland
# Processing Record 9 of Set 4 | sauda
# Processing Record 10 of Set 4 | carolina
# Processing Record 11 of Set 4 | dicabisagan
# Processing Record 12 of Set 4 | orgun
# orgun City not found. Skipping...
# Processing Record 13 of Set 4 | aktau
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | cagayan de tawi-tawi
# cagayan de tawi-tawi City not found. Skipping...
# Processing Record 16 of Set 4 | young
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | malinyi
# Processing Record 19 of Set 4 | iwanai
# Processing Record 20 of Set 4 | victor harbor
# Processing Record 21 of Set 4 | samusu
# samusu City not found. Skipping...
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | qaqortoq
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | pelym
# Processing Record 26 of Set 4 | kaminskiy
# Processing Record 27 of Set 4 | mtwara
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | grand-santi
# Processing Record 31 of Set 4 | noumea
# Processing Record 32 of Set 4 | nhulunbuy
# Processing Record 33 of Set 4 | gogrial
# Processing Record 34 of Set 4 | guerrero negro
# Processing Record 35 of Set 4 | ituni
# ituni City not found. Skipping...
# Processing Record 36 of Set 4 | skibbereen
# Processing Record 37 of Set 4 | kruisfontein
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | mazagao
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | dronten
# Processing Record 42 of Set 4 | jutai
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | havoysund
# Processing Record 45 of Set 4 | coahuayana
# Processing Record 46 of Set 4 | oyonnax
# Processing Record 47 of Set 4 | aden
# Processing Record 48 of Set 4 | sumbawa
# sumbawa City not found. Skipping...
# Processing Record 49 of Set 4 | illoqqortoormiut
# illoqqortoormiut City not found. Skipping...
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | uporovo
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | egvekinot
# Processing Record 6 of Set 5 | parkersburg
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | odienne
# Processing Record 9 of Set 5 | sterling
# Processing Record 10 of Set 5 | manitouwadge
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | kanungu
# Processing Record 13 of Set 5 | ipixuna
# Processing Record 14 of Set 5 | palabuhanratu
# palabuhanratu City not found. Skipping...
# Processing Record 15 of Set 5 | saint george
# Processing Record 16 of Set 5 | carballo
# Processing Record 17 of Set 5 | yeppoon
# Processing Record 18 of Set 5 | ariquemes
# Processing Record 19 of Set 5 | morondava
# Processing Record 20 of Set 5 | la ligua
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | xai-xai
# Processing Record 23 of Set 5 | umm lajj
# Processing Record 24 of Set 5 | khandyga
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | najran
# Processing Record 27 of Set 5 | saleaula
# saleaula City not found. Skipping...
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | nome
# Processing Record 30 of Set 5 | warqla
# warqla City not found. Skipping...
# Processing Record 31 of Set 5 | sonoita
# Processing Record 32 of Set 5 | kharan
# Processing Record 33 of Set 5 | bargal
# bargal City not found. Skipping...
# Processing Record 34 of Set 5 | muncar
# Processing Record 35 of Set 5 | abu kamal
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | castro
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | lata
# Processing Record 41 of Set 5 | bredasdorp
# Processing Record 42 of Set 5 | bani walid
# Processing Record 43 of Set 5 | gari
# Processing Record 44 of Set 5 | lorengau
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | deer lake
# Processing Record 47 of Set 5 | kismayo
# Processing Record 48 of Set 5 | ahuimanu
# Processing Record 49 of Set 5 | lebu
# Processing Record 50 of Set 5 | colesberg
# Processing Record 1 of Set 6 | ngukurr
# ngukurr City not found. Skipping...
# Processing Record 2 of Set 6 | burns lake
# Processing Record 3 of Set 6 | grenfell
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | dinghai
# Processing Record 6 of Set 6 | rongcheng
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | sao joao da barra
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | ericeira
# Processing Record 11 of Set 6 | ucluelet
# Processing Record 12 of Set 6 | forrest city
# Processing Record 13 of Set 6 | hvide sande
# Processing Record 14 of Set 6 | bababe
# bababe City not found. Skipping...
# Processing Record 15 of Set 6 | southbridge
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | balkanabat
# Processing Record 18 of Set 6 | vestmannaeyjar
# Processing Record 19 of Set 6 | louisbourg
# louisbourg City not found. Skipping...
# Processing Record 20 of Set 6 | yumen
# Processing Record 21 of Set 6 | tabukiniberu
# tabukiniberu City not found. Skipping...
# Processing Record 22 of Set 6 | emmaus
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | avera
# Processing Record 26 of Set 6 | maxixe
# Processing Record 27 of Set 6 | masuda
# Processing Record 28 of Set 6 | cabra
# Processing Record 29 of Set 6 | turukhansk
# Processing Record 30 of Set 6 | amderma
# amderma City not found. Skipping...
# Processing Record 31 of Set 6 | hella
# Processing Record 32 of Set 6 | guaxupe
# Processing Record 33 of Set 6 | paoua
# Processing Record 34 of Set 6 | jibuti
# Processing Record 35 of Set 6 | ust-kuyga
# Processing Record 36 of Set 6 | lahaina
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | attawapiskat
# attawapiskat City not found. Skipping...
# Processing Record 39 of Set 6 | vaasa
# Processing Record 40 of Set 6 | karaton
# Processing Record 41 of Set 6 | tazovskiy
# Processing Record 42 of Set 6 | dotnuva
# Processing Record 43 of Set 6 | nizhneyansk
# nizhneyansk City not found. Skipping...
# Processing Record 44 of Set 6 | vila franca do campo
# Processing Record 45 of Set 6 | luanda
# Processing Record 46 of Set 6 | vostok
# Processing Record 47 of Set 6 | bandarbeyla
# Processing Record 48 of Set 6 | mwinilunga
# Processing Record 49 of Set 6 | buin
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | shangzhi
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | killybegs
# Processing Record 4 of Set 7 | ekuvukeni
# Processing Record 5 of Set 7 | uruguaiana
# Processing Record 6 of Set 7 | kharp
# Processing Record 7 of Set 7 | valenca
# Processing Record 8 of Set 7 | adelaide
# Processing Record 9 of Set 7 | benguela
# Processing Record 10 of Set 7 | kricim
# kricim City not found. Skipping...
# Processing Record 11 of Set 7 | fukue
# Processing Record 12 of Set 7 | sarkand
# Processing Record 13 of Set 7 | flin flon
# Processing Record 14 of Set 7 | svetlyy
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | larsnes
# Processing Record 18 of Set 7 | asfi
# Processing Record 19 of Set 7 | srivardhan
# Processing Record 20 of Set 7 | yamada
# Processing Record 21 of Set 7 | wamba
# Processing Record 22 of Set 7 | manzhouli
# Processing Record 23 of Set 7 | riyadh
# Processing Record 24 of Set 7 | sentyabrskiy
# sentyabrskiy City not found. Skipping...
# Processing Record 25 of Set 7 | scottsbluff
# Processing Record 26 of Set 7 | tynda
# Processing Record 27 of Set 7 | karaul
# karaul City not found. Skipping...
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | lompoc
# Processing Record 30 of Set 7 | senmonorom
# senmonorom City not found. Skipping...
# Processing Record 31 of Set 7 | hambantota
# Processing Record 32 of Set 7 | bur gabo
# bur gabo City not found. Skipping...
# Processing Record 33 of Set 7 | meyungs
# meyungs City not found. Skipping...
# Processing Record 34 of Set 7 | ponta delgada
# Processing Record 35 of Set 7 | leua
# Processing Record 36 of Set 7 | shieli
# Processing Record 37 of Set 7 | barneveld
# Processing Record 38 of Set 7 | changji
# Processing Record 39 of Set 7 | tacoronte
# Processing Record 40 of Set 7 | porto seguro
# Processing Record 41 of Set 7 | laguna
# Processing Record 42 of Set 7 | kristianstad
# Processing Record 43 of Set 7 | jaypur
# Processing Record 44 of Set 7 | clarence town
# Processing Record 45 of Set 7 | evensk
# Processing Record 46 of Set 7 | tambun
# Processing Record 47 of Set 7 | maceio
# Processing Record 48 of Set 7 | vanimo
# Processing Record 49 of Set 7 | bogotol
# Processing Record 50 of Set 7 | grand centre
# grand centre City not found. Skipping...
# Processing Record 1 of Set 8 | muli
# Processing Record 2 of Set 8 | baishishan
# Processing Record 3 of Set 8 | pozoblanco
# Processing Record 4 of Set 8 | byron bay
# Processing Record 5 of Set 8 | san cristobal
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | mapastepec
# Processing Record 8 of Set 8 | ola
# Processing Record 9 of Set 8 | halalo
# halalo City not found. Skipping...
# Processing Record 10 of Set 8 | yarim
# Processing Record 11 of Set 8 | westport
# Processing Record 12 of Set 8 | grass valley
# Processing Record 13 of Set 8 | poum
# Processing Record 14 of Set 8 | ulaangom
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | mazamari
# Processing Record 17 of Set 8 | longlac
# longlac City not found. Skipping...
# Processing Record 18 of Set 8 | marcona
# marcona City not found. Skipping...
# Processing Record 19 of Set 8 | cabinda
# Processing Record 20 of Set 8 | montemor-o-novo
# Processing Record 21 of Set 8 | port hardy
# Processing Record 22 of Set 8 | seoul
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | dingle
# Processing Record 25 of Set 8 | richmond
# Processing Record 26 of Set 8 | tumannyy
# tumannyy City not found. Skipping...
# Processing Record 27 of Set 8 | lolua
# lolua City not found. Skipping...
# Processing Record 28 of Set 8 | boa vista
# Processing Record 29 of Set 8 | saryshagan
# saryshagan City not found. Skipping...
# Processing Record 30 of Set 8 | katima mulilo
# Processing Record 31 of Set 8 | honiara
# Processing Record 32 of Set 8 | kieta
# Processing Record 33 of Set 8 | magadan
# Processing Record 34 of Set 8 | jambi
# Processing Record 35 of Set 8 | goderich
# Processing Record 36 of Set 8 | mangai
# Processing Record 37 of Set 8 | tocopilla
# Processing Record 38 of Set 8 | walvis bay
# Processing Record 39 of Set 8 | qui nhon
# Processing Record 40 of Set 8 | tucupita
# Processing Record 41 of Set 8 | kokopo
# Processing Record 42 of Set 8 | lundazi
# Processing Record 43 of Set 8 | valdosta
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | rampur hat
# Processing Record 46 of Set 8 | eyl
# Processing Record 47 of Set 8 | aasiaat
# Processing Record 48 of Set 8 | mahon
# Processing Record 49 of Set 8 | san quintin
# Processing Record 50 of Set 8 | kerema
# Processing Record 1 of Set 9 | miranorte
# miranorte City not found. Skipping...
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | sobolevo
# Processing Record 5 of Set 9 | shirwal
# Processing Record 6 of Set 9 | la orilla
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | khani
# Processing Record 9 of Set 9 | grindavik
# Processing Record 10 of Set 9 | gibara
# Processing Record 11 of Set 9 | cherskiy
# Processing Record 12 of Set 9 | waitati
# Processing Record 13 of Set 9 | ilulissat
# Processing Record 14 of Set 9 | mrirt
# mrirt City not found. Skipping...
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | impfondo
# Processing Record 17 of Set 9 | camabatela
# Processing Record 18 of Set 9 | vizianagaram
# Processing Record 19 of Set 9 | fort-shevchenko
# Processing Record 20 of Set 9 | hualmay
# Processing Record 21 of Set 9 | athabasca
# Processing Record 22 of Set 9 | kangasala
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | raudeberg
# Processing Record 25 of Set 9 | amapa
# Processing Record 26 of Set 9 | turan
# Processing Record 27 of Set 9 | cabatuan
# Processing Record 28 of Set 9 | san isidro
# Processing Record 29 of Set 9 | raub
# Processing Record 30 of Set 9 | devonport
# Processing Record 31 of Set 9 | burgeo
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | gamba
# Processing Record 34 of Set 9 | taltal
# Processing Record 35 of Set 9 | mbaiki
# Processing Record 36 of Set 9 | kudahuvadhoo
# Processing Record 37 of Set 9 | touros
# Processing Record 38 of Set 9 | sorvag
# sorvag City not found. Skipping...
# Processing Record 39 of Set 9 | sibiti
# Processing Record 40 of Set 9 | dubai
# Processing Record 41 of Set 9 | waingapu
# Processing Record 42 of Set 9 | muros
# Processing Record 43 of Set 9 | santiago del estero
# Processing Record 44 of Set 9 | the valley
# Processing Record 45 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 9 | ketchikan
# Processing Record 47 of Set 9 | grand river south east
# grand river south east City not found. Skipping...
# Processing Record 48 of Set 9 | ternate
# Processing Record 49 of Set 9 | bansang
# Processing Record 50 of Set 9 | berdigestyakh
# Processing Record 1 of Set 10 | hendijan
# hendijan City not found. Skipping...
# Processing Record 2 of Set 10 | talcahuano
# Processing Record 3 of Set 10 | saint-augustin
# Processing Record 4 of Set 10 | tubruq
# tubruq City not found. Skipping...
# Processing Record 5 of Set 10 | fort nelson
# Processing Record 6 of Set 10 | viligili
# viligili City not found. Skipping...
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | stornoway
# Processing Record 9 of Set 10 | bairiki
# Processing Record 10 of Set 10 | challans
# Processing Record 11 of Set 10 | afua
# Processing Record 12 of Set 10 | red bluff
# Processing Record 13 of Set 10 | kodinsk
# Processing Record 14 of Set 10 | ostrovnoy
# Processing Record 15 of Set 10 | ugoofaaru
# Processing Record 16 of Set 10 | bathsheba
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | ambilobe
# Processing Record 19 of Set 10 | salamanca
# Processing Record 20 of Set 10 | bemidji
# Processing Record 21 of Set 10 | kindu
# Processing Record 22 of Set 10 | dunedin
# Processing Record 23 of Set 10 | araouane
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | jiblah
# Processing Record 26 of Set 10 | rawson
# Processing Record 27 of Set 10 | severo-kurilsk
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | arawa
# Processing Record 30 of Set 10 | tottori
# Processing Record 31 of Set 10 | foumbot
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | camacha
# Processing Record 34 of Set 10 | smithers
# Processing Record 35 of Set 10 | itoman
# Processing Record 36 of Set 10 | flinders
# Processing Record 37 of Set 10 | armacao dos buzios
# armacao dos buzios City not found. Skipping...
# Processing Record 38 of Set 10 | plakhtiyivka
# Processing Record 39 of Set 10 | herat
# Processing Record 40 of Set 10 | am timan
# Processing Record 41 of Set 10 | terney
# Processing Record 42 of Set 10 | riviere-du-loup
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | salalah
# Processing Record 47 of Set 10 | dunmore town
# Processing Record 48 of Set 10 | wenling
# Processing Record 49 of Set 10 | verkhnevilyuysk
# Processing Record 50 of Set 10 | oussouye
# Processing Record 1 of Set 11 | cairns
# Processing Record 2 of Set 11 | camapua
# Processing Record 3 of Set 11 | siddipet
# Processing Record 4 of Set 11 | makhachkala
# Processing Record 5 of Set 11 | ewa beach
# Processing Record 6 of Set 11 | waipawa
# Processing Record 7 of Set 11 | bobcaygeon
# Processing Record 8 of Set 11 | bundaberg
# Processing Record 9 of Set 11 | atambua
# Processing Record 10 of Set 11 | salisbury
# Processing Record 11 of Set 11 | mata
# Processing Record 12 of Set 11 | yerbogachen
# Processing Record 13 of Set 11 | gawler
# Processing Record 14 of Set 11 | sangar
# Processing Record 15 of Set 11 | sorland
# Processing Record 16 of Set 11 | fazendas de almeirim
# Processing Record 17 of Set 11 | kamphaeng phet
# Processing Record 18 of Set 11 | coihueco
# Processing Record 19 of Set 11 | samarkand
# Processing Record 20 of Set 11 | pointe michel
# Processing Record 21 of Set 11 | micheweni
# Processing Record 22 of Set 11 | bourail
# Processing Record 23 of Set 11 | torit
# Processing Record 24 of Set 11 | tosya
# Processing Record 25 of Set 11 | provideniya
# Processing Record 26 of Set 11 | bull savanna
# Processing Record 27 of Set 11 | deputatskiy
# Processing Record 28 of Set 11 | yerofey pavlovich
# Processing Record 29 of Set 11 | belyy yar
# Processing Record 30 of Set 11 | rossosh
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | fairbanks
# Processing Record 33 of Set 11 | powell river
# Processing Record 34 of Set 11 | katobu
# Processing Record 35 of Set 11 | mariental
# Processing Record 36 of Set 11 | kedrovyy
# Processing Record 37 of Set 11 | kopyevo
# kopyevo City not found. Skipping...
# Processing Record 38 of Set 11 | tocache
# Processing Record 39 of Set 11 | san matias
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | preobrazheniye
# Processing Record 42 of Set 11 | sur
# Processing Record 43 of Set 11 | gurupi
# Processing Record 44 of Set 11 | burica
# burica City not found. Skipping...
# Processing Record 45 of Set 11 | alofi
# Processing Record 46 of Set 11 | tautira
# Processing Record 47 of Set 11 | alta floresta
# Processing Record 48 of Set 11 | grand gaube
# Processing Record 49 of Set 11 | aborlan
# Processing Record 50 of Set 11 | matara
# Processing Record 1 of Set 12 | san rafael
# Processing Record 2 of Set 12 | hobyo
# Processing Record 3 of Set 12 | forbes
# Processing Record 4 of Set 12 | pa daet
# Processing Record 5 of Set 12 | comodoro rivadavia
# Processing Record 6 of Set 12 | cache creek
# Processing Record 7 of Set 12 | cajamar
# Processing Record 8 of Set 12 | sao miguel do araguaia
# Processing Record 9 of Set 12 | long beach
# Processing Record 10 of Set 12 | hofn
# Processing Record 11 of Set 12 | acari
# Processing Record 12 of Set 12 | houma
# Processing Record 13 of Set 12 | toliary
# toliary City not found. Skipping...
# Processing Record 14 of Set 12 | mandiana
# Processing Record 15 of Set 12 | coquimbo
# Processing Record 16 of Set 12 | taoudenni
# Processing Record 17 of Set 12 | shache
# Processing Record 18 of Set 12 | kuressaare
# Processing Record 19 of Set 12 | mascote
# Processing Record 20 of Set 12 | golden
# Processing Record 21 of Set 12 | sami
# Processing Record 22 of Set 12 | tartagal
# Processing Record 23 of Set 12 | elban
# Processing Record 24 of Set 12 | galveston
# Processing Record 25 of Set 12 | sept-iles
# Processing Record 26 of Set 12 | siderno
# Processing Record 27 of Set 12 | santa cruz
# Processing Record 28 of Set 12 | kitimat
# Processing Record 29 of Set 12 | coihaique
# Processing Record 30 of Set 12 | beringovskiy
# Processing Record 31 of Set 12 | gizo
# Processing Record 32 of Set 12 | port augusta
# Processing Record 33 of Set 12 | araguari
# Processing Record 34 of Set 12 | plettenberg bay
# Processing Record 35 of Set 12 | mitsamiouli
# Processing Record 36 of Set 12 | saint-pascal
# saint-pascal City not found. Skipping...
# Processing Record 37 of Set 12 | jalu
# Processing Record 38 of Set 12 | benin
# Processing Record 39 of Set 12 | katav-ivanovsk
# Processing Record 40 of Set 12 | yulara
# Processing Record 41 of Set 12 | bambanglipuro
# Processing Record 42 of Set 12 | hay river
# Processing Record 43 of Set 12 | maumere
# Processing Record 44 of Set 12 | half moon bay
# Processing Record 45 of Set 12 | victoria
# Processing Record 46 of Set 12 | patin-ay
# Processing Record 47 of Set 12 | aljezur
# Processing Record 48 of Set 12 | nizhniy odes
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | geraldton
# Processing Record 1 of Set 13 | urucara
# Processing Record 2 of Set 13 | garissa
# Processing Record 3 of Set 13 | poopo
# Processing Record 4 of Set 13 | traverse city
# Processing Record 5 of Set 13 | igarka
# Processing Record 6 of Set 13 | kolondieba
# Processing Record 7 of Set 13 | anadyr
# Processing Record 8 of Set 13 | gardan diwal
# gardan diwal City not found. Skipping...
# Processing Record 9 of Set 13 | russell
# Processing Record 10 of Set 13 | rio grande
# Processing Record 11 of Set 13 | erzin
# Processing Record 12 of Set 13 | dukat
# Processing Record 13 of Set 13 | durban
# Processing Record 14 of Set 13 | vao
# Processing Record 15 of Set 13 | lasa
# Processing Record 16 of Set 13 | antalaha
# Processing Record 17 of Set 13 | muborak
# Processing Record 18 of Set 13 | koutsouras
# Processing Record 19 of Set 13 | milingimbi
# milingimbi City not found. Skipping...
# Processing Record 20 of Set 13 | malwan
# malwan City not found. Skipping...
# Processing Record 21 of Set 13 | conde
# Processing Record 22 of Set 13 | virginia beach
# Processing Record 23 of Set 13 | porto novo
# Processing Record 24 of Set 13 | kenai
# Processing Record 25 of Set 13 | marawi
# Processing Record 26 of Set 13 | ruwi
# Processing Record 27 of Set 13 | matay
# Processing Record 28 of Set 13 | dartford
# Processing Record 29 of Set 13 | ahumada
# ahumada City not found. Skipping...
# Processing Record 30 of Set 13 | calama
# Processing Record 31 of Set 13 | agadez
# Processing Record 32 of Set 13 | halifax
# Processing Record 33 of Set 13 | port blair
# Processing Record 34 of Set 13 | general pico
# Processing Record 35 of Set 13 | maneadero
# Processing Record 36 of Set 13 | klyuchevskiy
# Processing Record 37 of Set 13 | kysyl-syr
# Processing Record 38 of Set 13 | lodja
# Processing Record 39 of Set 13 | itarema
# Processing Record 40 of Set 13 | umkomaas
# Processing Record 41 of Set 13 | dakar
# Processing Record 42 of Set 13 | upington
# Processing Record 43 of Set 13 | chase
# Processing Record 44 of Set 13 | kavaratti
# Processing Record 45 of Set 13 | blagoyevo
# Processing Record 46 of Set 13 | naryan-mar
# Processing Record 47 of Set 13 | hoquiam
# Processing Record 48 of Set 13 | leh
# Processing Record 49 of Set 13 | bratsk
# Processing Record 50 of Set 13 | kalmunai
# Processing Record 1 of Set 14 | paso de carrasco
# Processing Record 2 of Set 14 | ulladulla
# Processing Record 3 of Set 14 | yarkovo
# Processing Record 4 of Set 14 | mount gambier
# Processing Record 5 of Set 14 | stoyba
# stoyba City not found. Skipping...
# Processing Record 6 of Set 14 | lanzhou
# Processing Record 7 of Set 14 | samalaeulu
# samalaeulu City not found. Skipping...
# Processing Record 8 of Set 14 | san vicente
# Processing Record 9 of Set 14 | husavik
# Processing Record 10 of Set 14 | sinjar
# Processing Record 11 of Set 14 | khambhaliya
# Processing Record 12 of Set 14 | zeya
# Processing Record 13 of Set 14 | jinxiang
# Processing Record 14 of Set 14 | zhuhai
# Processing Record 15 of Set 14 | sayyan
# Processing Record 16 of Set 14 | nguiu
# nguiu City not found. Skipping...
# Processing Record 17 of Set 14 | diu
# Processing Record 18 of Set 14 | umea
# Processing Record 19 of Set 14 | manbij
# Processing Record 20 of Set 14 | kalabo
# Processing Record 21 of Set 14 | brufut
# Processing Record 22 of Set 14 | gangotri
# gangotri City not found. Skipping...
# Processing Record 23 of Set 14 | ust-nera
# Processing Record 24 of Set 14 | gilgit
# Processing Record 25 of Set 14 | loukhi
# Processing Record 26 of Set 14 | mandsaur
# Processing Record 27 of Set 14 | kwinana
# Processing Record 28 of Set 14 | cabo rojo
# Processing Record 29 of Set 14 | brandon
# Processing Record 30 of Set 14 | alotau
# alotau City not found. Skipping...
# Processing Record 31 of Set 14 | belmonte
# Processing Record 32 of Set 14 | opuwo
# Processing Record 33 of Set 14 | bantogon
# Processing Record 34 of Set 14 | kurilsk
# Processing Record 35 of Set 14 | elk river
# Processing Record 36 of Set 14 | karakendzha
# karakendzha City not found. Skipping...
# Processing Record 37 of Set 14 | bonavista
# Processing Record 38 of Set 14 | kralendijk
# Processing Record 39 of Set 14 | havelock
# Processing Record 40 of Set 14 | karkaralinsk
# karkaralinsk City not found. Skipping...
# Processing Record 41 of Set 14 | palkonda
# Processing Record 42 of Set 14 | timmins
# Processing Record 43 of Set 14 | port moresby
# Processing Record 44 of Set 14 | gimbi
# Processing Record 45 of Set 14 | hazleton
# Processing Record 46 of Set 14 | keti bandar
# Processing Record 47 of Set 14 | hanmer springs
# Processing Record 48 of Set 14 | cap-aux-meules
# Processing Record 49 of Set 14 | sinnamary
# Processing Record 50 of Set 14 | maniitsoq
# Processing Record 1 of Set 15 | saint-pierre
# Processing Record 2 of Set 15 | humberto de campos
# Processing Record 3 of Set 15 | palamos
# Processing Record 4 of Set 15 | kanganpur
# Processing Record 5 of Set 15 | tezu
# Processing Record 6 of Set 15 | gat
# Processing Record 7 of Set 15 | borovoy
# Processing Record 8 of Set 15 | cuamba
# Processing Record 9 of Set 15 | tiarei
# Processing Record 10 of Set 15 | carrollton
# Processing Record 11 of Set 15 | awbari
# Processing Record 12 of Set 15 | ilhabela
# Processing Record 13 of Set 15 | cerritos
# Processing Record 14 of Set 15 | acapulco
# Processing Record 15 of Set 15 | portland
# Processing Record 16 of Set 15 | huntsville
# Processing Record 17 of Set 15 | wellington
# Processing Record 18 of Set 15 | karoi
# Processing Record 19 of Set 15 | palmer
# Processing Record 20 of Set 15 | aflu
# aflu City not found. Skipping...
# Processing Record 21 of Set 15 | berlevag
# Processing Record 22 of Set 15 | rurrenabaque
# Processing Record 23 of Set 15 | gayny
# Processing Record 24 of Set 15 | krasnogorskoye
# Processing Record 25 of Set 15 | beysehir
# Processing Record 26 of Set 15 | koupela
# Processing Record 27 of Set 15 | kingman
# Processing Record 28 of Set 15 | beidao
# Processing Record 29 of Set 15 | kathmandu
# Processing Record 30 of Set 15 | fuxin
# Processing Record 31 of Set 15 | inirida
# Processing Record 32 of Set 15 | wuwei
# Processing Record 33 of Set 15 | brigantine
# Processing Record 34 of Set 15 | les cayes
# Processing Record 35 of Set 15 | kenora
# Processing Record 36 of Set 15 | benjamin constant
# Processing Record 37 of Set 15 | buraydah
# Processing Record 38 of Set 15 | kyrnasivka
# Processing Record 39 of Set 15 | amga
# Processing Record 40 of Set 15 | urubicha
# Processing Record 41 of Set 15 | ekibastuz
# Processing Record 42 of Set 15 | dawlatabad
# Processing Record 43 of Set 15 | atar
# Processing Record 44 of Set 15 | komsomolskiy
# Processing Record 45 of Set 15 | nanyang
# Processing Record 46 of Set 15 | augusto correa
# Processing Record 47 of Set 15 | merano
# Processing Record 48 of Set 15 | mauganj
# Processing Record 49 of Set 15 | volodarskiy
# Processing Record 50 of Set 15 | fevralsk
# fevralsk City not found. Skipping...
# Processing Record 1 of Set 16 | lugovskoy
# Processing Record 2 of Set 16 | pho chai
# Processing Record 3 of Set 16 | chimbote
# Processing Record 4 of Set 16 | aswan
# Processing Record 5 of Set 16 | thinadhoo
# Processing Record 6 of Set 16 | gumdag
# Processing Record 7 of Set 16 | sorong
# Processing Record 8 of Set 16 | farafenni
# Processing Record 9 of Set 16 | baoding
# Processing Record 10 of Set 16 | yadrin
# Processing Record 11 of Set 16 | los llanos de aridane
# Processing Record 12 of Set 16 | skoghall
# Processing Record 13 of Set 16 | srednekolymsk
# Processing Record 14 of Set 16 | krasnooktyabrskiy
# Processing Record 15 of Set 16 | utiroa
# utiroa City not found. Skipping...
# Processing Record 16 of Set 16 | makasar
# Processing Record 17 of Set 16 | moose factory
# Processing Record 18 of Set 16 | portree
# Processing Record 19 of Set 16 | akureyri
# Processing Record 20 of Set 16 | tanshui
# tanshui City not found. Skipping...
# Processing Record 21 of Set 16 | abilene
# Processing Record 22 of Set 16 | magway
# Processing Record 23 of Set 16 | severouralsk
# Processing Record 24 of Set 16 | akyab
# Processing Record 25 of Set 16 | odweyne
# Processing Record 26 of Set 16 | yanam
# Processing Record 27 of Set 16 | newport
# Processing Record 28 of Set 16 | xichang
# Processing Record 29 of Set 16 | mao
# Processing Record 30 of Set 16 | college
# Processing Record 31 of Set 16 | zhigansk
# Processing Record 32 of Set 16 | sao felix do xingu
# Processing Record 33 of Set 16 | camocim
# Processing Record 34 of Set 16 | williams lake
# Processing Record 35 of Set 16 | lazarev
# Processing Record 36 of Set 16 | lima
# Processing Record 37 of Set 16 | porbandar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# After collecting all our data, 
# we can tally the number of cities in the city_data array of dictionaries using the len() function.
len(city_data)
# Out:
# 720

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Chokurdakh      RU  70.6333  147.9167     21.27        87
# 1  Nikolayevsk-Na-Amure      RU  53.1406  140.7300     32.68        82
# 2                Marzuq      YE  14.4000   46.4667     79.56        51
# 3                Viedma      AR -40.8135  -62.9967     49.19        60
# 4              Katsuura      JP  35.1333  140.3000     72.19        80
# 5              Klaksvik      FO  62.2266   -6.5890     43.72        75
# 6               Isangel      VU -19.5500  169.2667     80.71        89
# 7          Punta Arenas      CL -53.1500  -70.9167     48.31        40
# 8                 Rundu      NA -17.9333   19.7667     71.49        55
# 9                  Hilo      US  19.7297 -155.0900     81.81        74
#
#    Cloudiness  Wind Speed Current Description
# 0         100       11.30     overcast clouds
# 1          61        3.33       broken clouds
# 2           4        2.64           clear sky
# 3          92       19.98     overcast clouds
# 4          70        8.77       broken clouds
# 5          86        6.89     overcast clouds
# 6          75        0.00       broken clouds
# 7           0       18.41           clear sky
# 8          41        5.53    scattered clouds
# 9          20        8.05          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
